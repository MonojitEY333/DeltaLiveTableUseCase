# %%
# %sql
CREATE TABLE IF NOT EXISTS ecommerce.rw.lineitem_rw DEEP CLONE samples.tpch.lineitem;
CREATE TABLE IF NOT EXISTS ecommerce.rw.customer_rw DEEP CLONE samples.tpch.customer;
CREATE TABLE IF NOT EXISTS ecommerce.rw.orders_rw DEEP CLONE samples.tpch.orders;

# %%
# %sql
select * from ecommerce.dbo.bronze_customers

# %%
# %sql
select * from ecommerce.dbo.bronze_customers order by c_custkey

# %%
# %sql
select * from ecommerce.sch.silver_customer_scd_2
 where c_custkey in (4,5)

# %%
# %sql
INSERT INTO ecommerce.rw.customer_rw(
c_custkey,
c_name,
c_address,
c_nationkey,
c_phone,
c_acctbal,
c_mktsegment,
c_comment)
VALUES
    (
        4,
        'Customer#000000004',
        'XxVSJsLAGtn',
        4,
        '14-128-190-5944',
        2866.83,
        'MACHINERY',
        'new Comment 12'
    ),
    (
        5,
        'Customer#000000005',
        'KvpyuHCplrB84WgAiGV6sYpZq7Tj',
        3,
        '13-750-942-6364',
        794.47,
        'HOUSEHOLD',
        'new Comment 14 '
    )

# %%
# %sql
select * from ecommerce.rw.customer_rw
where c_custkey >=4 and c_custkey<=5
order by customer_rw.c_custkey

# %%
# %sql
select count(*) from ecommerce.rw.customer_rw

# %%
# %sql
select * from ecommerce.sch.silver_customer_scd_2
where c_custkey>=4 and c_custkey<=5

# %%
# %sql
select * from ecommerce.rw.orders_rw 
order by o_orderkey desc limit 1

# %%
# %sql
--insert data into order raw table 

INSERT INTO ecommerce.rw.orders_rw (
    o_orderkey,
    o_custkey,
    o_orderstatus,
    o_totalprice,
    o_orderdate,
    o_orderpriority,
    o_clerk,
    o_shippriority,
    o_comment
) VALUES
(30000005, 184501, 'O', 900000, '1996-01-02', '5-LOW', 'Clerk#000004753', 0, 'nstructions sleep furiously among'),
(30000006, 390010, 'O', 70000, '1996-12-01', '1-URGENT', 'Clerk#000004396', 0, 'foxes. pending accounts at the pending, silent asymptot'),
(30000007, 616570, 'F', 933803, '1993-10-14', '5-LOW', 'Clerk#000004772', 0, 'sly final accounts boost. carefully regular ideas cajole carefully. depos'),
(30000008, 683881, 'O', 83393, '1995-10-11', '5-LOW', 'Clerk#000000617', 0, 'sits. slyly regular warthogs cajole. regular, regular theodolites acro'),
(30000009, 222424, 'F', 239032, '1994-07-30', '5-LOW', 'Clerk#000004624', 0, 'quickly. bold deposits sleep slyly. packages use slyly');

# %%
# %sql
select * from ecommerce.sch.gold_monthly_sales
# Out:
# Databricks visualization. Run in Databricks to view.

# %%
# %sql
select * from ecommerce.sch.gold_product_performance
# Out:
# Databricks visualization. Run in Databricks to view.

# %%
# %sql
select * from ecommerce.sch.gold_customer_orders
